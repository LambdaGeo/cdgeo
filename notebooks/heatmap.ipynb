# %%
import geopandas as gpd

# %%
escolas = gpd.read_file("../data/escolas_publicas_ilha_maranhao.zip")
escolas.plot()
# Out:
# <Axes: >

# %%
escolas.head()
# Out:
#                                             Restriçã  \
# 0  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 1  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 2  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 3  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 4                                  ESCOLA PARALISADA
#
#                                            Escola  Código_IN  UF  \
# 0                 UEB POETA GONCALVES DIAS - CAIC   21007438  MA
# 1                    CENTRO DE ENSINO ERASMO DIAS   21007446  MA
# 2  CENTRO DE ENSINO DR LUIZ SERGIO CABRAL BARRETO   21007454  MA
# 3                             UEB SAGRADA FAMILIA   21007535  MA
# 4                               UEB ESCOLINHA ABC   21007713  MA
#
#         Município Localizaç  \
# 0  Paço do Lumiar     Rural
# 1  Paço do Lumiar    Urbana
# 2  Paço do Lumiar     Rural
# 3  Paço do Lumiar     Rural
# 4  Paço do Lumiar     Rural
#
#                                           Localidade Categoria_  \
# ...

# %%
escolas.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
municipios = gpd.read_file("../data/municipios_ilha_maranhao.zip")
ax = municipios.plot()
escolas.plot(ax=ax, color="red")
# Out:
# <Axes: >

# %%
import folium

# %%
print(municipios.crs)
# Out:
# EPSG:4674

# %%
municipios = municipios.to_crs("EPSG:4326")

# %%
print(municipios.crs)
# Out:
# EPSG:4326

# %%
centro = [ -2.5117883,-44.000084]

# %%
municipios.head()
# Out:
#       id  version                 name source inserted_a updated_at category  \
# 0  16366        2  S�o Jos� de Ribamar   IBGE 2023-04-26 2023-04-26     city
# 1  17321        2             S�o Lu�s   IBGE 2023-04-26 2023-04-26     city
# 2  20146        2       Pa�o do Lumiar   IBGE 2023-04-26 2023-04-26     city
# 3  20991        2               Raposa   IBGE 2023-04-26 2023-04-26     city
#
#   category_n  area_ha                                           geometry
# 0  Munic�pio      0.0  POLYGON ((-44.18366 -2.46437, -44.18363 -2.464...
# 1  Munic�pio      0.0  MULTIPOLYGON (((-44.41227 -2.7983, -44.41246 -...
# 2  Munic�pio      0.0  POLYGON ((-44.07581 -2.46172, -44.07524 -2.461...
# 3  Munic�pio      0.0  POLYGON ((-44.05258 -2.40475, -44.05145 -2.404...

# %%
municipios.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4 non-null      int32
#  1   version     4 non-null      int32
#  2   name        4 non-null      object
#  3   source      4 non-null      object
#  4   inserted_a  4 non-null      datetime64[ms]
#  5   updated_at  4 non-null      datetime64[ms]
#  6   category    4 non-null      object
#  7   category_n  4 non-null      object
#  8   area_ha     4 non-null      float64
#  9   geometry    4 non-null      geometry
# dtypes: datetime64[ms](2), float64(1), geometry(1), int32(2), object(4)
# memory usage: 416.0+ bytes

# %%
municipios["inserted_a"] = municipios["inserted_a"].astype(str)
municipios["updated_at"] = municipios["updated_at"].astype(str)

# %%
municipios.plot()
# Out:
# <Axes: >

# %%
municipios.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4 non-null      int32
#  1   version     4 non-null      int32
#  2   name        4 non-null      object
#  3   source      4 non-null      object
#  4   inserted_a  4 non-null      object
#  5   updated_at  4 non-null      object
#  6   category    4 non-null      object
#  7   category_n  4 non-null      object
#  8   area_ha     4 non-null      float64
#  9   geometry    4 non-null      geometry
# dtypes: float64(1), geometry(1), int32(2), object(6)
# memory usage: 416.0+ bytes

# %%
basemap = folium.Map(location=centro)

folium.GeoJson(
    municipios,
    name="Camada GeoDataFrame",
).add_to(basemap)

basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
escolas.dropna(inplace=True)

# %%
from folium.plugins import HeatMap

# %%
pontos = [[geom.y, geom.x] for geom in escolas.geometry]
HeatMap(pontos, radius=15).add_to(basemap)
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
escolas.geometry
# Out:
# 0      POINT (-44.17555 -2.53896)
# 1      POINT (-44.17363 -2.54482)
# 2        POINT (-44.165 -2.50236)
# 3      POINT (-44.17014 -2.53686)
# 4                            None
#                   ...
# 562    POINT (-44.16258 -2.46758)
# 563    POINT (-44.10463 -2.41675)
# 564    POINT (-44.15539 -2.51333)
# 565    POINT (-44.17525 -2.47622)
# 566                          None
# Name: geometry, Length: 567, dtype: geometry

# %%
escolas_privadas = gpd.read_file("../data/escolas_privadas_ilha_maranhao.zip")
escolas_privadas.plot()
# Out:
# <Axes: >

# %%
escolas_privadas.dropna(subset=['geometry'],inplace=True)
escolas_privadas
# Out:
#                                               Restriçã  \
# 0    ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 1    ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 4    ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 5    ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 7    ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# ..                                                 ...
# 640  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 641  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 642  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 643  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 645  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
#
#                                                 Escola  Código_IN  UF  \
# 0            CENTRO EDUCACIONAL SAO FRANCISCO DE ASSIS   21007519  MA
# 1                    ESCOLA COMUNITARIA PADRE MAURICIO   21007578  MA
# 4                              ESCOLINHA PAZ DE CRISTO   21009074  MA
# ...

# %%
basemap2 = folium.Map(location=centro)

folium.GeoJson(
    municipios,
    name="Camada GeoDataFrame",
).add_to(basemap2)

basemap2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
pontos = [[geom.y, geom.x] for geom in escolas_privadas.geometry]
HeatMap(pontos, radius=15).add_to(basemap2)
basemap2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
escolas_privadas.geometry
# Out:
# 0       POINT (-44.1668 -2.53541)
# 1       POINT (-44.1729 -2.54624)
# 2                            None
# 3                            None
# 4      POINT (-44.06845 -2.54559)
#                   ...
# 641    POINT (-44.20293 -2.54189)
# 642    POINT (-44.28748 -2.53363)
# 643    POINT (-44.25818 -2.55265)
# 644                          None
# 645      POINT (-44.204 -2.54179)
# Name: geometry, Length: 646, dtype: geometry
