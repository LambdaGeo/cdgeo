# %%
import pandas as pd

# %%
url= 'https://drive.google.com/uc?id=1hw-SPd8EMBgsqXUKu3FpOhWe4NANgu30'
df = pd.read_excel(url)

# %%
df
# Out:
#                  Estado        Região  População            PIB
# 0                  Acre         Norte     829780    21374000000
# 1               Alagoas      Nordeste    3125254    76266000000
# 2                 Amapá         Norte     774268    20100000000
# 3              Amazonas         Norte    3952262   131531000000
# 4                 Bahia      Nordeste   14659023   352618000000
# 5                 Ceará      Nordeste    8936431   194885000000
# 6      Distrito Federal  Centro-Oeste    2923369   286944000000
# 7        Espírito Santo       Sudeste    3975100   186337000000
# 8                 Goiás  Centro-Oeste    6950976   269628000000
# 9              Maranhão      Nordeste    6800605   124981000000
# 10          Mato Grosso  Centro-Oeste    3784239   233390000000
# 11   Mato Grosso do Sul  Centro-Oeste    2833742   142204000000
# 12         Minas Gerais       Sudeste   20732660   857593000000
# 13                 Pará         Norte    8442962   262905000000
# ...

# %% [markdown]
# https://www.ibge.gov.br/geociencias/organizacao-do-territorio/malhas-territoriais/15774-malhas.html
#
#
# unidades da federacao

# %%
url = "https://geoftp.ibge.gov.br/organizacao_do_territorio/malhas_territoriais/malhas_municipais/municipio_2022/Brasil/BR/BR_UF_2022.zip"

# %%
import geopandas as gpd

# %%
ufs = gpd.read_file(url)
ufs.plot()
# Out:
# <Axes: >

# %%
ufs.head()
# Out:
#   CD_UF      NM_UF SIGLA_UF NM_REGIAO     AREA_KM2  \
# 0    12       Acre       AC     Norte   164173.429
# 1    13   Amazonas       AM     Norte  1559255.881
# 2    15       Pará       PA     Norte  1245870.704
# 3    16      Amapá       AP     Norte   142470.762
# 4    17  Tocantins       TO     Norte   277423.627
#
#                                             geometry
# 0  POLYGON ((-68.79282 -10.99957, -68.79367 -10.9...
# 1  POLYGON ((-56.76292 -3.23221, -56.76789 -3.242...
# 2  MULTIPOLYGON (((-48.97548 -0.19834, -48.97487 ...
# 3  MULTIPOLYGON (((-51.04561 -0.05088, -51.05422 ...
# 4  POLYGON ((-48.2483 -13.19239, -48.24844 -13.19...

# %%
ufs_merge = pd.merge(ufs, df, left_on="NM_UF", right_on='Estado', how='inner')
ufs_merge.head()
# Out:
#   CD_UF      NM_UF SIGLA_UF NM_REGIAO     AREA_KM2  \
# 0    12       Acre       AC     Norte   164173.429
# 1    13   Amazonas       AM     Norte  1559255.881
# 2    15       Pará       PA     Norte  1245870.704
# 3    16      Amapá       AP     Norte   142470.762
# 4    17  Tocantins       TO     Norte   277423.627
#
#                                             geometry     Estado Região  \
# 0  POLYGON ((-68.79282 -10.99957, -68.79367 -10.9...       Acre  Norte
# 1  POLYGON ((-56.76292 -3.23221, -56.76789 -3.242...   Amazonas  Norte
# 2  MULTIPOLYGON (((-48.97548 -0.19834, -48.97487 ...       Pará  Norte
# 3  MULTIPOLYGON (((-51.04561 -0.05088, -51.05422 ...      Amapá  Norte
# 4  POLYGON ((-48.2483 -13.19239, -48.24844 -13.19...  Tocantins  Norte
#
#    População           PIB
# 0     829780   21374000000
# 1    3952262  131531000000
# 2    8442962  262905000000
# 3     774268   20100000000
# 4    1584306   51781000000

# %%
ufs_merge.plot(column="População", cmap="RdYlGn", legend=True)
# Out:
# <Axes: >

# %%
ufs_merge.plot(column="PIB", cmap="RdYlGn", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# pip install mapclassify

# %%
ufs_merge.plot(column="PIB", cmap="RdYlGn", scheme= "Quantiles", legend=False)
# Out:
# <Axes: >

# %%
ufs_merge.plot(column="População", cmap="RdYlGn", scheme= "Quantiles", legend=False)
# Out:
# <Axes: >

# %%
ufs_merge.plot(column="População", cmap="RdYlGn", scheme= "naturalbreaks", legend=False)
# Out:
# <Axes: >
